# %% [markdown]
# <a href="https://colab.research.google.com/github/tusjain/LinearAlgebraNumPy/blob/main/MatrixInNumPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a = np.array([[1],
[3],
[7],
[2]])
print("a =", a)
A = np.matrix([[1, 3, 7, 2],
[5, 8, -9, 0],
[6, -7, 11, 12]])
print("A =", A)
# Out:
# a = [[1]
#  [3]
#  [7]
#  [2]]
# A = [[ 1  3  7  2]
#  [ 5  8 -9  0]
#  [ 6 -7 11 12]]

# %% [markdown]
# Vector ![vector.JPG](data:image/jpeg;base64,...)
#
# Matrix ![11111.png](data:image/png;base64,...)
